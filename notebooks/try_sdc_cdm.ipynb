# %%
# %pip install -r ../requirements.txt

import sqlite3
import glob
import os
from lxml import etree
from import_sdc_form_sqlite import process_xml
from import_vol_v_message_sqlite import import_data_from_hl7

DB_FILEPATH = "public/sdc_cdm.db"
# Out:
# Requirement already satisfied: lxml==5.3.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (5.3.0)
# Requirement already satisfied: SQLAlchemy==2.0.35 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (2.0.35)
# Requirement already satisfied: psycopg2-binary==2.9.9 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (2.9.9)
# Requirement already satisfied: notebook==7.2.2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (7.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from SQLAlchemy==2.0.35->-r ../requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from SQLAlchemy==2.0.35->-r ../requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from notebook==7.2.2->-r ../requirements.txt (line 4)) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from notebook==7.2.2->-r ../requirements.txt (line 4)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from notebook==7.2.2->-r ../requirements.txt (line 4)) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from notebook==7.2.2->-r ../requirements.txt (line 4)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from notebook==7.2.2->-r ../requirements.txt (line 4)) (6.4.1)
# Requirement already satisfied: anyio>=3.1.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (4.6.2.post1)
# Requirement already satisfied: argon2-cffi>=21.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.21.0)
# Requirement already satisfied: pyzmq>=24 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (66.1.1)
# Requirement already satisfied: babel>=2.10 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: certifi in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.8.7)
# Requirement already satisfied: ipython>=7.23.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (8.29.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: psutil in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (6.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (4.3.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (6.2.0)
# Requirement already satisfied: defusedxml in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.18.0)
# Requirement already satisfied: tinycss2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.2.3)
# Requirement already satisfied: ptyprocess in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: webencodings in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: decorator in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.0.48)
# Requirement already satisfied: stack-data in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (4.9.0)
# Requirement already satisfied: fqdn in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: isoduration in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: uri-template in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (24.8.0)
# Requirement already satisfied: six>=1.5 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.6)
# Requirement already satisfied: pycparser in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.8.4)
# Requirement already satisfied: wcwidth in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.4.1)
# Requirement already satisfied: pure-eval in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.9.0.20241003)
# Note: you may need to restart the kernel to use updated packages.

# %%
if os.path.exists(DB_FILEPATH):
    print(f"Deleting existing database file: {DB_FILEPATH}")
    os.remove(DB_FILEPATH)

# Connect to the SQLite database (creates the database file if it doesn't exist)
conn = sqlite3.connect(DB_FILEPATH)
cursor = conn.cursor()
print("Connected to the SQLite database.")

# Get a list of all .sql files in the ./ddl directory
sql_files = glob.glob('../database/ddl/sqlite/*.sql')

# Sort the files alphanumerically
sql_files.sort()

# Display the files to be executed
print("SQL files to be executed in order:")
for file in sql_files:
    print(os.path.basename(file))

# Execute each SQL file
for sql_file in sql_files:
    print(f"\nExecuting {os.path.basename(sql_file)}...")
    with open(sql_file, 'r') as file:
        sql_script = file.read()
    try:
        cursor.executescript(sql_script)
        print(f"Finished executing {os.path.basename(sql_file)}.")
    except Exception as e:
        print(f"An error occurred while executing {os.path.basename(sql_file)}: {e}")

# Commit changes and close the connection
conn.commit()
conn.close()

print("Database changes committed and connection closed.")
# Out:
# Deleting existing database file: public/sdc_cdm.db
# Connected to the SQLite database.
# SQL files to be executed in order:
# 1_OMOPCDM_sqlite_5.4_ddl.sql
# 2_OMOPCDM_sqlite_5.4_primary_keys.sql
# 3_OMOPCDM_sqlite_5.4_indices.sql
# 4_OMOPCDM_sqlite_5.4_constraints.sql
# 5_SDC_sqlite.sql
#
# Executing 1_OMOPCDM_sqlite_5.4_ddl.sql...
# Finished executing 1_OMOPCDM_sqlite_5.4_ddl.sql.
#
# Executing 2_OMOPCDM_sqlite_5.4_primary_keys.sql...
# Finished executing 2_OMOPCDM_sqlite_5.4_primary_keys.sql.
#
# Executing 3_OMOPCDM_sqlite_5.4_indices.sql...
# Finished executing 3_OMOPCDM_sqlite_5.4_indices.sql.
#
# Executing 4_OMOPCDM_sqlite_5.4_constraints.sql...
# Finished executing 4_OMOPCDM_sqlite_5.4_constraints.sql.
#
# Executing 5_SDC_sqlite.sql...
# Finished executing 5_SDC_sqlite.sql.
# Database changes committed and connection closed.

# %%
conn = sqlite3.connect(DB_FILEPATH)
cursor = conn.cursor()

namespaces = {
    "sdc": "urn:ihe:qrph:sdc:2016",
    "xsi": "http://www.w3.org/2001/XMLSchema-instance",
    "xsd": "http://www.w3.org/2001/XMLSchema",
}

# Import SDC templates
v2_messages = glob.glob(os.path.join("../sample_data/sdc_templates", "*.xml"))

# Iterate over each XML file
for message in v2_messages:
    # Read the XML content
    with open(message, "r", encoding="utf-8") as file:
        message_str = file.read()

    tree = etree.parse(message)
    root = tree.getroot()

    form_design = root.find("sdc:FormDesign", namespaces)
    if form_design is None:
        form_design = root

    if form_design is None:
        print(f"No Form Design found in {os.path.basename(message)}")
        continue
    print(f"Form Design: {form_design}")

    # Extract column values from the XML content
    sdcformdesignid = form_design.get("ID")
    baseuri = form_design.get("baseURI")
    lineage = form_design.get("lineage")
    version = form_design.get("version")
    fulluri = form_design.get("fullURI")
    formtitle = form_design.get("formTitle")
    sdc_xml = etree.tostring(form_design).decode("utf-8")
    doctype = "FD"  # TODO: Parse from fullURI

    # Insert the data into the database
    try:
        cursor.execute(
            """
            INSERT INTO main.templatesdcclass (
                sdcformdesignid, baseuri, lineage, version, fulluri, formtitle, sdc_xml, doctype
            ) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
        """,
            (
                sdcformdesignid,
                baseuri,
                lineage,
                version,
                fulluri,
                formtitle,
                sdc_xml,
                doctype,
            ),
        )
        print(f"Inserted data from {os.path.basename(message)} into the database.")
    except Exception as e:
        print(
            f"An error occurred while inserting data from {os.path.basename(message)}: {e}"
        )

# Commit the changes
conn.commit()
print("All XML data has been inserted into the database.")

cursor.execute("SELECT COUNT(*) FROM main.templatesdcclass;")
count = cursor.fetchone()[0]
print(f"\nTotal records inserted: {count}")

# Commit changes and close the connection
conn.close()
# Out:
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3c800>
# Inserted data from Kidney.Bx.149_2.005.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b25f200>
# Inserted data from Neuroblastoma.Res.153_4.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc15a80>
# Inserted data from ExGonad.GCT.Bx.369_2.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b30e300>
# Inserted data from Stomach.NET.Res.201_3.000.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4c91c6c0>
# Inserted data from Skin.Merkel.Res.198_2.003.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320800>
# Inserted data from Prostate.Needle.Specimen.Bx.508_1.001.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f340>
# Inserted data from Small_Int.Res.166_3.003.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320bc0>
# Inserted data from Colon.NET.Res.196_3.000.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4c91c6c0>
# Inserted data from Skin.Melanoma.Bmk.253_1.000.022.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b25f200>
# Inserted data from PNET_Ewing.Bx.209_3.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320800>
# Inserted data from Breast.Invasive.Bx.362_1.004.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc15a80>
# Inserted data from UreterRenalPelvis.Res.337_3.005.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3c800>
# Inserted data from Skin.Inv_Melanoma.Res.579_1.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b30e300>
# Inserted data from Rhabdomyosarcoma.Bx.365_2.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3c800>
# Inserted data from Breast.Invasive.Res.189_4.009.021.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f340>
# Inserted data from Uvea.Mel.Res.184_3.002.021.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4c91c6c0>
# Inserted data from Vagina.Res.186_3.006.031.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from Bladder.Res.180_3.004.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc15a80>
# Inserted data from Tumor.Bx.326_1.001.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b30e300>
# Inserted data from HN.Pharynx.Res.208_3.006.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b327540>
# Inserted data from HN.SCC.Res.549_1.000.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b25f200>
# Inserted data from Urethra.Res.203_3.006.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320bc0>
# Inserted data from Appendix.NET.Res.193_3.000.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from Gallbladder.Res.144_3.003.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f340>
# Inserted data from Appendix.Res.135_4.001.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b25f200>
# Inserted data from Stomach.GIST.Res.145_3.005.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320800>
# Inserted data from Testis.RO.171_3.005.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc15a80>
# Inserted data from HN.Bmk.522_1.001.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b30e300>
# Inserted data from Tumor.Res.312_1.002.021.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320bc0>
# Inserted data from Duod.Amp.NET.Res.342_2.000.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc15a80>
# Inserted data from Kidney.Res.150_3.004.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from Lung.Res.119_3.008.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b326f80>
# Inserted data from Bladder.Bx.TURBT.202_1.007.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4ccac5c0>
# Inserted data from Anus.Bx.TDE.133_4.000.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b25f200>
# Inserted data from Heme.PlasmaCell_Immuno.Bx.Res.572_1.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from Kidney.Wilms.Bx.Res.188_3.004.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc15a80>
# Inserted data from CentralNervousSystem.Bx.Res.551_1.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from Gynecologic.Bmk.567_1.001.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4c91c6c0>
# Inserted data from Kidney.Wilms.Bx.366_2.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from IHC.Bmk.515_1.002.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b30e300>
# Inserted data from Trophoblast.Res.DC.176_3.002.021.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc16140>
# Inserted data from ColoRectal.Bx.127_2.013.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f340>
# Inserted data from Skin.Inv_Melanoma.Bx.578_1.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320bc0>
# Inserted data from Breast.DCIS.Bx.360_1.002.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320800>
# Inserted data from Breast.DCIS.Res.211_3.003.021.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc15a80>
# Inserted data from Adrenal.Bx.Res.129_3.007.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc16140>
# Inserted data from ExGonad.GCT.Res.212_3.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320bc0>
# Inserted data from PleuraPericard.Res.160_3.003.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f340>
# Inserted data from Bone.Bx.136_2.008.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b30e300>
# Inserted data from Stomach.Res.170_3.006.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4c91c6c0>
# Inserted data from Vagina.Bx.185_2.004.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320800>
# Inserted data from Penis.Bx.Res.210_3.004.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4ccac5c0>
# Inserted data from Retinoblastoma.163_3.002.021.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc16140>
# Inserted data from Vulva.Res.187_4.000.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f980>
# Inserted data from Panc.Exo.Bx.Res.157_3.004.032.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b25f200>
# Inserted data from Ampulla.Res.131_3.004.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f340>
# Inserted data from Esophagus.Res.141_3.003.021.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b30e300>
# Inserted data from HN.Nasal.Res.207_3.006.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc16140>
# Inserted data from Cervix.Trach.Hys.PlvEx.182_4.004.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4c91c6c0>
# Inserted data from Urethra.Bx.204_1.008.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from Breast.Bmk.169_1.008.021.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320800>
# Inserted data from Thymus.Res.174_3.003.021.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f340>
# Inserted data from Testis.RPL.172_3.004.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc16140>
# Inserted data from Rhabdomyosarcoma.Res.164_4.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320bc0>
# Inserted data from DNA.MMR.Bmk.347_1.000.031.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc15a80>
# Inserted data from Prostate.TURP.190_2.010.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from Heme.Myeloid_Mixed_Amb.Bx.Res.571_1.000.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b30e300>
# Inserted data from HN.Oral.Res.206_3.008.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc16140>
# Inserted data from BileDuctPH.Res.195_2.004.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f340>
# Inserted data from Liver.HCC.Res.151_3.006.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from Bone.Res.138_3.004.021.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f980>
# Inserted data from Lung.Bmk.227_2.001.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b25f200>
# Inserted data from Prostate.Res.128_3.006.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320800>
# Inserted data from Soft.Tissue.Bx.167_2.008.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc15a80>
# Inserted data from BileDuctIH.Res.194_2.003.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4c91c6c0>
# Inserted data from Uterus.Sarc.Res.216_2.005.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320bc0>
# Inserted data from Thyroid.Res.175_4.005.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc16140>
# Inserted data from Jejunum_Ileum.NET.Res.343_2.000.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f340>
# Inserted data from HN.MajorSalivary.Res.152_3.007.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc15a80>
# Inserted data from Prostate.Needle.Case.Bx.507_1.001.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4ccac5c0>
# Inserted data from Breast.Phyllodes.547_1.001.011.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b25f200>
# Inserted data from Panc.Endo.Bx.Res.156_4.000.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b327300>
# Inserted data from Colon.Bmk.228_1.002.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b30e300>
# Inserted data from Anus.AP.Res.134_4.000.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from HN.Larynx.Bx.Res.205_3.006.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4c91c6c0>
# Inserted data from PNET_Ewing.Res.161_3.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320800>
# Inserted data from Liver.Hepatoblastoma.Bx.363_2.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from Stomach.HER2.Bmk.223_1.003.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f240>
# Inserted data from Thyroid.Bmk.255_1.001.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f980>
# Inserted data from UreterRenalPelvis.Bx.179_3.003.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4ccac5c0>
# Inserted data from ColoRectal.Res.126_3.008.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b30e300>
# Inserted data from Liver.Hepatoblastoma.Bx.Res.147_4.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b25f200>
# Inserted data from Uterus.Hys.Bx.117_4.000.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320bc0>
# Inserted data from Stomach.GIST.Bx.197_2.009.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4ccac5c0>
# Inserted data from Stomach.GIST.Bmk.242_1.003.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320800>
# Inserted data from Soft.Tissue.Res.168_3.004.021.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from BileDuctDE.Res.142_3.004.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f240>
# Inserted data from Neuroblastoma.Bx.364_2.000.000.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from Cervix.Cone.LEEP.183_2.009.021.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f4c91c6c0>
# Inserted data from Ovary_FT_Perit.Bx.Res.336_1.007.001.REL_sdcFDF.xml into the database.
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2bc3f000>
# Inserted data from Heme.Lymphoid.Bx.Res.570_1.000.000.REL_sdcFDF.xml into the database.
# All XML data has been inserted into the database.
#
# Total records inserted: 101

# %%
# Import SDC forms
conn = sqlite3.connect(DB_FILEPATH)
cursor = conn.cursor()

# Import SDC templates
v2_messages = glob.glob(os.path.join("../sample_data/sdc_xml", "*.xml"))

# Iterate over each XML file
for message in v2_messages:
    # Read the XML content
    with open(message, "r", encoding="utf-8") as file:
        message_str = file.read()

    tree = etree.parse(message)
    root = tree.getroot()
    process_xml(root, cursor)

cursor.close()
conn.commit()
conn.close()
# Out:
# INFO:crud_sqlite:Inserting new TemplateSdcClass: {'sdcformdesignid': 'Adrenal.Bx.Res.129_3.002.011.RC1_sdcFDF', 'baseuri': 'cap.org', 'lineage': 'Adrenal.Bx.Res.129', 'version': '3.002.011.RC1', 'fulluri': '_baseURI=cap.org&_lineage=Adrenal.Bx.Res.129&_version=3.002.011.RC1&_docType=sdcFDF', 'formtitle': 'ADRENAL GLAND', 'sdc_xml': '<FormDesign xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns="urn:ihe:qrph:sdc:2016" order="0" ID="Adrenal.Bx.Res.129_3.002.011.RC1_sdcFDF" baseURI="cap.org" fullURI="_baseURI=cap.org&amp;_lineage=Adrenal.Bx.Res.129&amp;_version=3.002.011.RC1&amp;_docType=sdcFDF" filename="Adrenal.Bx.Res.129_3.002.011.RC1_sdcFDF.xml" lineage="Adrenal.Bx.Res.129" formTitle="ADRENAL GLAND" version="3.002.011.RC1">\n    <Property name="Copyright" type="CAPeCC_static_text" styleClass="copyright" order="1" propName="Copyright" val="(c) 2018 College of American Pathologists.  All rights reserved.  License required for use."/>\n    <Property name="GenericHeaderText" type="CAPeCC_static_text" order="2" propName="GenericHeaderText" val="Surgical Pathology Cancer Case Summary (Checklist)"/>\n    <Property name="Category" type="CAPeCC_meta" order="3" propName="Category" val="Endocrine"/>\n    <Property name="OfficialName" type="CAPeCC_meta" order="4" propName="OfficialName" val="ADRENAL GLAND"/>\n    <Property name="CAP_ProtocolName" type="CAPeCC_meta" order="5" propName="CAP_ProtocolName" val="Adrenal Gland"/>\n    <Property name="CAP_ProtocolVersion" type="CAPeCC_meta" order="6" propName="CAP_ProtocolVersion" val="4.0.1.1"/>\n    <Property name="TemplateID" type="CAPeCC_meta" order="7" propName="TemplateID" val="129.100004300"/>\n    <Property name="Restrictions" type="CAPeCC_meta" order="8" propName="Restrictions" val="Please refer to the cancer protocol cover page (www.cap.org/cancerprotocols) for information about which tumor types and procedures can be reported using this template."/>\n    <Property name="CAP_Required" type="CAPeCC_meta" order="9" propName="CAP_Required" val="true"/>\n    <Property name="AccreditationDate" type="CAPeCC_meta dt.dateTime" order="10" propName="AccreditationDate" val="2/28/2018 12:00:00 AM"/>\n    <Property name="WebPostingDate" type="CAPeCC_meta dt.dateTime" order="11" propName="WebPostingDate" val="6/30/2017 12:00:00 AM"/>\n    <Property name="ShortName" type="CAPeCC_meta" order="12" propName="ShortName" val="Adrenal.Bx.Res"/>\n    <Property name="ApprovalStatus" type="CAPeCC_meta" order="13" propName="ApprovalStatus" val="RC1"/>\n    <Property name="AJCC_Version" type="CAPeCC_meta" order="14" propName="AJCC_Version" val="8th Edition"/>\n    <Body name="Body" order="15" ID="Adrenal.Bx.Res.129_3.002.011.RC1_sdcFDF_Body">\n      <ChildItems name="ch_Body" order="16">\n        <DisplayedItem name="DI_39617" order="17" ID="39617.100004300" title="# This checklist applies principally to adrenal carcinomas in adults. Pediatric adrenal cortical tumors have different criteria for malignancy and are, in general, treated under protocols that may differ significantly from the recommendations for adult- type tumors.">\n          <Property name="p_rptTxt_39617_1" order="18" propName="reportText" val="{no text}"/>\n        </DisplayedItem>\n        <Section name="S_4257" order="19" ID="4257.100004300" minCard="0">\n          <ChildItems name="ch_4257_1" order="20">\n            <Question name="Q_Tum_Site_2118" order="21" ID="2118.100004300" minCard="0" readOnly="true">\n              <Property name="p_rptTxt_2118_1" order="22" propName="reportText" val="{no text}"/>\n              <ListField name="lf_2118_2" order="23">\n                <List name="lst_2118_3" order="24">\n                  <ListItem name="LI_Adrenal_Gland_2119" order="25" ID="2119.100004300" title="Adrenal gland" selected="true">\n                    <Property name="p_rptTxt_2119_1" order="26" propName="reportText" val="{no text}"/>\n                  </ListItem>\n                ...
# INFO:crud_sqlite:Successfully added: {'sdcformdesignid': 'Adrenal.Bx.Res.129_3.002.011.RC1_sdcFDF', 'baseuri': 'cap.org', 'lineage': 'Adrenal.Bx.Res.129', 'version': '3.002.011.RC1', 'fulluri': '_baseURI=cap.org&_lineage=Adrenal.Bx.Res.129&_version=3.002.011.RC1&_docType=sdcFDF', 'formtitle': 'ADRENAL GLAND', 'sdc_xml': '<FormDesign xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns="urn:ihe:qrph:sdc:2016" order="0" ID="Adrenal.Bx.Res.129_3.002.011.RC1_sdcFDF" baseURI="cap.org" fullURI="_baseURI=cap.org&amp;_lineage=Adrenal.Bx.Res.129&amp;_version=3.002.011.RC1&amp;_docType=sdcFDF" filename="Adrenal.Bx.Res.129_3.002.011.RC1_sdcFDF.xml" lineage="Adrenal.Bx.Res.129" formTitle="ADRENAL GLAND" version="3.002.011.RC1">\n    <Property name="Copyright" type="CAPeCC_static_text" styleClass="copyright" order="1" propName="Copyright" val="(c) 2018 College of American Pathologists.  All rights reserved.  License required for use."/>\n    <Property name="GenericHeaderText" type="CAPeCC_static_text" order="2" propName="GenericHeaderText" val="Surgical Pathology Cancer Case Summary (Checklist)"/>\n    <Property name="Category" type="CAPeCC_meta" order="3" propName="Category" val="Endocrine"/>\n    <Property name="OfficialName" type="CAPeCC_meta" order="4" propName="OfficialName" val="ADRENAL GLAND"/>\n    <Property name="CAP_ProtocolName" type="CAPeCC_meta" order="5" propName="CAP_ProtocolName" val="Adrenal Gland"/>\n    <Property name="CAP_ProtocolVersion" type="CAPeCC_meta" order="6" propName="CAP_ProtocolVersion" val="4.0.1.1"/>\n    <Property name="TemplateID" type="CAPeCC_meta" order="7" propName="TemplateID" val="129.100004300"/>\n    <Property name="Restrictions" type="CAPeCC_meta" order="8" propName="Restrictions" val="Please refer to the cancer protocol cover page (www.cap.org/cancerprotocols) for information about which tumor types and procedures can be reported using this template."/>\n    <Property name="CAP_Required" type="CAPeCC_meta" order="9" propName="CAP_Required" val="true"/>\n    <Property name="AccreditationDate" type="CAPeCC_meta dt.dateTime" order="10" propName="AccreditationDate" val="2/28/2018 12:00:00 AM"/>\n    <Property name="WebPostingDate" type="CAPeCC_meta dt.dateTime" order="11" propName="WebPostingDate" val="6/30/2017 12:00:00 AM"/>\n    <Property name="ShortName" type="CAPeCC_meta" order="12" propName="ShortName" val="Adrenal.Bx.Res"/>\n    <Property name="ApprovalStatus" type="CAPeCC_meta" order="13" propName="ApprovalStatus" val="RC1"/>\n    <Property name="AJCC_Version" type="CAPeCC_meta" order="14" propName="AJCC_Version" val="8th Edition"/>\n    <Body name="Body" order="15" ID="Adrenal.Bx.Res.129_3.002.011.RC1_sdcFDF_Body">\n      <ChildItems name="ch_Body" order="16">\n        <DisplayedItem name="DI_39617" order="17" ID="39617.100004300" title="# This checklist applies principally to adrenal carcinomas in adults. Pediatric adrenal cortical tumors have different criteria for malignancy and are, in general, treated under protocols that may differ significantly from the recommendations for adult- type tumors.">\n          <Property name="p_rptTxt_39617_1" order="18" propName="reportText" val="{no text}"/>\n        </DisplayedItem>\n        <Section name="S_4257" order="19" ID="4257.100004300" minCard="0">\n          <ChildItems name="ch_4257_1" order="20">\n            <Question name="Q_Tum_Site_2118" order="21" ID="2118.100004300" minCard="0" readOnly="true">\n              <Property name="p_rptTxt_2118_1" order="22" propName="reportText" val="{no text}"/>\n              <ListField name="lf_2118_2" order="23">\n                <List name="lst_2118_3" order="24">\n                  <ListItem name="LI_Adrenal_Gland_2119" order="25" ID="2119.100004300" title="Adrenal gland" selected="true">\n                    <Property name="p_rptTxt_2119_1" order="26" propName="reportText" val="{no text}"/>\n                  </ListItem>\n                </List>\n   ...
# INFO:crud_sqlite:Successfully added: {'templateinstanceversionguid': None, 'templateinstanceversionuri': None, 'templatesdcfk': 102, 'instanceversiondate': None, 'diagreportprops': None, 'surgpathid': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'reporttext': None, 'pk': 1}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_4257', 'section_guid': '4257.100004300', 'q_text': None, 'q_instanceguid': '2118.100004300', 'q_id': 'Q_Tum_Site_2118', 'li_text': 'Adrenal gland', 'li_id': 'LI_Adrenal_Gland_2119', 'li_instanceguid': '2119.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '25', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 1}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17537', 'section_guid': '17537.100004300', 'q_text': 'Clinical History (specify)', 'q_instanceguid': '4156.100004300', 'q_id': 'Q_Oth_Non_Path_Findings_4156', 'li_text': None, 'li_id': None, 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '32', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 2}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17537', 'section_guid': '17537.100004300', 'q_text': 'Functional Status (Notes J and K)', 'q_instanceguid': '53772.100004300', 'q_id': 'Q_53772', 'li_text': 'Urinary 17-ketosteroids increased (10 mg / g creatinine / 24 hours)', 'li_id': 'LI_Urin_17-ketosteroids_increased_20900', 'li_instanceguid': '20900.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '38', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 3}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17537', 'section_guid': '17537.100004300', 'q_text': 'Functional Status (Notes J and K)', 'q_instanceguid': '53772.100004300', 'q_id': 'Q_53772', 'li_text': 'Cushing syndrome', 'li_id': 'LI_Cushing_Synd_20902', 'li_instanceguid': '20902.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '39', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 4}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17537', 'section_guid': '17537.100004300', 'q_text': 'Functional Status (Notes J and K)', 'q_instanceguid': '53772.100004300', 'q_id': 'Q_53772', 'li_text': 'Conn syndrome', 'li_id': 'LI_Conn_Synd_20904', 'li_instanceguid': '20904.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '40', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 5}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17537', 'section_guid': '17537.100004300', 'q_text': 'Functional Status (Notes J and K)', 'q_instanceguid': '53772.100004300', 'q_id': 'Q_53772', 'li_text': 'Virilization', 'li_id': 'LI_43052', 'li_instanceguid': '43052.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '41', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 6}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17537', 'section_guid': '17537.100004300', 'q_text': 'Functional Status (Notes J and K)', 'q_instanceguid': '53772.100004300', 'q_id': 'Q_53772', 'li_text': 'Feminization', 'li_id': 'LI_44618', 'li_instanceguid': '44618.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '42', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 7}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17537', 'section_guid': '17537.100004300', 'q_text': 'Functional Status (Notes J and K)', 'q_instanceguid': '53772.100004300', 'q_id': 'Q_53772', 'li_text': 'Weight loss', 'li_id': 'LI_Weight_Loss_20906', 'li_instanceguid': '20906.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '43', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 8}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17537', 'section_guid': '17537.100004300', 'q_text': 'Functional Status (Notes J and K)', 'q_instanceguid': '53772.100004300', 'q_id': 'Q_53772', 'li_text': 'Other (specify)', 'li_id': 'LI_Oth_20907', 'li_instanceguid': '20907.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '47', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 9}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17875', 'section_guid': '17875.100004300', 'q_text': 'Procedure', 'q_instanceguid': '42554.100004300', 'q_id': 'Q_Procedure_42554', 'li_text': 'Percutaneous needle biopsy', 'li_id': 'LI_50809', 'li_instanceguid': '50809.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '54', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 10}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17875', 'section_guid': '17875.100004300', 'q_text': 'Procedure', 'q_instanceguid': '42554.100004300', 'q_id': 'Q_Procedure_42554', 'li_text': 'Endoscopic directed biopsy (specify radiographic technique)', 'li_id': 'LI_46633', 'li_instanceguid': '46633.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '58', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 11}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17875', 'section_guid': '17875.100004300', 'q_text': 'Procedure', 'q_instanceguid': '42554.100004300', 'q_id': 'Q_Procedure_42554', 'li_text': 'Adrenalectomy, total', 'li_id': 'LI_Adrenalectomy_Total_2122', 'li_instanceguid': '2122.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '60', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 12}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17875', 'section_guid': '17875.100004300', 'q_text': 'Procedure', 'q_instanceguid': '42554.100004300', 'q_id': 'Q_Procedure_42554', 'li_text': 'Adrenalectomy, partial', 'li_id': 'LI_Adrenalectomy_Part_2121', 'li_instanceguid': '2121.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '61', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 13}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17875', 'section_guid': '17875.100004300', 'q_text': 'Procedure', 'q_instanceguid': '42554.100004300', 'q_id': 'Q_Procedure_42554', 'li_text': 'Other (specify)', 'li_id': 'LI_Oth_2123', 'li_instanceguid': '2123.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '65', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 14}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17875', 'section_guid': '17875.100004300', 'q_text': 'Procedure', 'q_instanceguid': '42554.100004300', 'q_id': 'Q_Procedure_42554', 'li_text': 'Not specified', 'li_id': 'LI_NS_2124', 'li_instanceguid': '2124.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '67', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 15}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17875', 'section_guid': '17875.100004300', 'q_text': 'Specimen Laterality', 'q_instanceguid': '52756.100004300', 'q_id': 'Q_52756', 'li_text': 'Right', 'li_id': 'LI_Right_2126', 'li_instanceguid': '2126.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '71', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 16}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17875', 'section_guid': '17875.100004300', 'q_text': 'Specimen Laterality', 'q_instanceguid': '52756.100004300', 'q_id': 'Q_52756', 'li_text': 'Left', 'li_id': 'LI_Left_2127', 'li_instanceguid': '2127.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '72', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 17}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17875', 'section_guid': '17875.100004300', 'q_text': 'Specimen Laterality', 'q_instanceguid': '52756.100004300', 'q_id': 'Q_52756', 'li_text': 'Bilateral', 'li_id': 'LI_56812', 'li_instanceguid': '56812.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '73', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 18}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17875', 'section_guid': '17875.100004300', 'q_text': 'Specimen Laterality', 'q_instanceguid': '52756.100004300', 'q_id': 'Q_52756', 'li_text': 'Not specified', 'li_id': 'LI_NS_2128', 'li_instanceguid': '2128.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '74', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 19}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17875', 'section_guid': '17875.100004300', 'q_text': 'Specimen Laterality', 'q_instanceguid': '52756.100004300', 'q_id': 'Q_52756', 'li_text': 'Other (specify)', 'li_id': 'LI_Oth_20866', 'li_instanceguid': '20866.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '78', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 20}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17877', 'section_guid': '17877.100004300', 'q_text': 'Tumor Extension', 'q_instanceguid': '51265.100004300', 'q_id': 'Q_51265', 'li_text': 'No evidence of primary tumor', 'li_id': 'LI_44186', 'li_instanceguid': '44186.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '159', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 21}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17877', 'section_guid': '17877.100004300', 'q_text': 'Tumor Extension', 'q_instanceguid': '51265.100004300', 'q_id': 'Q_51265', 'li_text': 'Tumor confined to adrenal cortex without invasion through tumor capsule (if present)', 'li_id': 'LI_50695', 'li_instanceguid': '50695.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '160', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 22}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17877', 'section_guid': '17877.100004300', 'q_text': 'Tumor Extension', 'q_instanceguid': '51265.100004300', 'q_id': 'Q_51265', 'li_text': 'Tumor invades into or through the adrenal capsule', 'li_id': 'LI_39537', 'li_instanceguid': '39537.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '162', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 23}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17877', 'section_guid': '17877.100004300', 'q_text': 'Tumor Extension', 'q_instanceguid': '51265.100004300', 'q_id': 'Q_51265', 'li_text': 'Tumor invades into extra-adrenal structures (specify)', 'li_id': 'LI_52315', 'li_instanceguid': '52315.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '166', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 24}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17877', 'section_guid': '17877.100004300', 'q_text': 'Tumor Extension', 'q_instanceguid': '51265.100004300', 'q_id': 'Q_51265', 'li_text': 'Tumor invades into other adjacent organ(s)', 'li_id': 'LI_56271', 'li_instanceguid': '56271.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '168', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 25}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17877', 'section_guid': '17877.100004300', 'q_text': 'Tumor Extension', 'q_instanceguid': '51265.100004300', 'q_id': 'Q_51265', 'li_text': 'Cannot be assessed', 'li_id': 'LI_Indeterminate_51911', 'li_instanceguid': '51911.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '186', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 26}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Lymphovascular Invasion (Note F)', 'q_instanceguid': '42474.100004300', 'q_id': 'Q_42474', 'li_text': 'Not identified', 'li_id': 'LI_Not_Id_2159', 'li_instanceguid': '2159.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '194', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 27}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Lymphovascular Invasion (Note F)', 'q_instanceguid': '42474.100004300', 'q_id': 'Q_42474', 'li_text': 'Large vessel, renal vein (including when identified clinically)', 'li_id': 'LI_52962', 'li_instanceguid': '52962.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '195', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 28}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Lymphovascular Invasion (Note F)', 'q_instanceguid': '42474.100004300', 'q_id': 'Q_42474', 'li_text': 'Large vessel, vena cava (including when identified clinically)', 'li_id': 'LI_59454', 'li_instanceguid': '59454.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '197', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 29}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Lymphovascular Invasion (Note F)', 'q_instanceguid': '42474.100004300', 'q_id': 'Q_42474', 'li_text': 'Small vessel (capillary lymphatic)', 'li_id': 'LI_Sm_Vessel_20881', 'li_instanceguid': '20881.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '199', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 30}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Lymphovascular Invasion (Note F)', 'q_instanceguid': '42474.100004300', 'q_id': 'Q_42474', 'li_text': 'Cannot be determined', 'li_id': 'LI_Indeterminate_2161', 'li_instanceguid': '2161.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '202', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 31}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Tumor Description', 'q_instanceguid': '48491.100004300', 'q_id': 'Q_48491', 'li_text': 'Hemorrhagic', 'li_id': 'LI_Hemorrhagic_20863', 'li_instanceguid': '20863.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '207', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 32}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Tumor Description', 'q_instanceguid': '48491.100004300', 'q_id': 'Q_48491', 'li_text': 'Necrotic', 'li_id': 'LI_Necrotic_20864', 'li_instanceguid': '20864.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '208', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 33}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Tumor Description', 'q_instanceguid': '48491.100004300', 'q_id': 'Q_48491', 'li_text': 'Other (specify)', 'li_id': 'LI_Oth_20865', 'li_instanceguid': '20865.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '212', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 34}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Histologic Type (Notes C through E)', 'q_instanceguid': '59852.100004300', 'q_id': 'Q_59852', 'li_text': 'Adrenal cortical carcinoma, oncocytic type', 'li_id': 'LI_46925', 'li_instanceguid': '46925.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '86', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 35}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Histologic Type (Notes C through E)', 'q_instanceguid': '59852.100004300', 'q_id': 'Q_59852', 'li_text': 'Adrenal cortical carcinoma', 'li_id': 'LI_Adrenal_Cortical_Ca_2117', 'li_instanceguid': '2117.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '87', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 36}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Histologic Type (Notes C through E)', 'q_instanceguid': '59852.100004300', 'q_id': 'Q_59852', 'li_text': 'Adrenal cortical carcinoma, myxoid type', 'li_id': 'LI_44449', 'li_instanceguid': '44449.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '88', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 37}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Histologic Type (Notes C through E)', 'q_instanceguid': '59852.100004300', 'q_id': 'Q_59852', 'li_text': 'Adrenal cortical carcinoma, sarcomatoid type', 'li_id': 'LI_59162', 'li_instanceguid': '59162.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '89', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 38}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Histologic Grade (Notes C through E)', 'q_instanceguid': '49275.100004300', 'q_id': 'Q_49275', 'li_text': 'Low grade (<= 20 mitoses / 50 high-power fields)', 'li_id': 'LI_53603', 'li_instanceguid': '53603.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '99', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 39}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Histologic Grade (Notes C through E)', 'q_instanceguid': '49275.100004300', 'q_id': 'Q_49275', 'li_text': 'High grade (> 20 mitoses / 50 high-power fields)', 'li_id': 'LI_48634', 'li_instanceguid': '48634.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '101', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 40}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Histologic Grade (Notes C through E)', 'q_instanceguid': '49275.100004300', 'q_id': 'Q_49275', 'li_text': 'Cannot be assessed (explain)#', 'li_id': 'LI_54648', 'li_instanceguid': '54648.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '108', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 41}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Tumor Size (Note A)', 'q_instanceguid': '2129.100004300', 'q_id': 'Q_Tum_Size_2129', 'li_text': 'Greatest dimension in Centimeters (cm)', 'li_id': 'LI_TSize1_2131', 'li_instanceguid': '2131.100004300', 'li_parentguid': None, 'response': None, 'units': 'cm', 'units_system': 'UCOM', 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '116', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 42}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Tumor Size (Note A)', 'q_instanceguid': '2129.100004300', 'q_id': 'Q_Tum_Size_2129', 'li_text': 'Cannot be determined (explain)', 'li_id': 'LI_CBD_2130', 'li_instanceguid': '2130.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '136', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 43}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Tumor Weight (Note B)', 'q_instanceguid': '40496.100004300', 'q_id': 'Q_Tum_Gland_Weight_40496', 'li_text': 'Specify weight (g)', 'li_id': 'LI_Tum_Gland_Weight_g_44761', 'li_instanceguid': '44761.100004300', 'li_parentguid': None, 'response': None, 'units': 'grams', 'units_system': 'UCOM', 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '145', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 44}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17879', 'section_guid': '17879.100004300', 'q_text': 'Tumor Weight (Note B)', 'q_instanceguid': '40496.100004300', 'q_id': 'Q_Tum_Gland_Weight_40496', 'li_text': 'Cannot be determined', 'li_id': 'LI_NA_57476', 'li_instanceguid': '57476.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '151', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 45}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17878', 'section_guid': '17878.100004300', 'q_text': 'Margins', 'q_instanceguid': '2153.100004300', 'q_id': 'Q_Marg_Status_2153', 'li_text': 'Uninvolved by tumor', 'li_id': 'LI_MargUnv_Tum_2154', 'li_instanceguid': '2154.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '219', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 46}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17878', 'section_guid': '17878.100004300', 'q_text': 'Margins', 'q_instanceguid': '2153.100004300', 'q_id': 'Q_Marg_Status_2153', 'li_text': 'Involved by tumor', 'li_id': 'LI_Marg_Tum_2155', 'li_instanceguid': '2155.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '250', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 47}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17878', 'section_guid': '17878.100004300', 'q_text': 'Margins', 'q_instanceguid': '2153.100004300', 'q_id': 'Q_Marg_Status_2153', 'li_text': 'Cannot be assessed', 'li_id': 'LI_CBD_2157', 'li_instanceguid': '2157.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '268', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 48}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17878', 'section_guid': '17878.100004300', 'q_text': 'Margins', 'q_instanceguid': '2153.100004300', 'q_id': 'Q_Marg_Status_2153', 'li_text': 'Not applicable', 'li_id': 'LI_NA_20852', 'li_instanceguid': '20852.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '272', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 49}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17881', 'section_guid': '17881.100004300', 'q_text': 'Regional Lymph Nodes', 'q_instanceguid': '1867.100004300', 'q_id': 'Q_1867', 'li_text': 'No lymph nodes submitted or found', 'li_id': 'LI_No_LN_Id_1868', 'li_instanceguid': '1868.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '279', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 50}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': '?TNM Descriptors', 'q_instanceguid': '20880.100004300', 'q_id': 'Q_TNM_Descriptors_20880', 'li_text': '?Not applicable', 'li_id': 'LI_NA_22897', 'li_instanceguid': '22897.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '337', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 51}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': '?TNM Descriptors', 'q_instanceguid': '20880.100004300', 'q_id': 'Q_TNM_Descriptors_20880', 'li_text': 'm (multiple primary tumors)', 'li_id': 'LI_m_20890', 'li_instanceguid': '20890.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '339', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 52}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': '?TNM Descriptors', 'q_instanceguid': '20880.100004300', 'q_id': 'Q_TNM_Descriptors_20880', 'li_text': 'r (recurrent)', 'li_id': 'LI_r_20891', 'li_instanceguid': '20891.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '340', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 53}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': '?TNM Descriptors', 'q_instanceguid': '20880.100004300', 'q_id': 'Q_TNM_Descriptors_20880', 'li_text': 'y (post-treatment)', 'li_id': 'LI_y_20892', 'li_instanceguid': '20892.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '341', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 54}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': 'Primary Tumor (pT)', 'q_instanceguid': '2137.100004300', 'q_id': 'Q_pT_2137', 'li_text': 'pTX: Primary tumor cannot be assessed', 'li_id': 'LI_pTX_2142', 'li_instanceguid': '2142.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '347', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 55}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': 'Primary Tumor (pT)', 'q_instanceguid': '2137.100004300', 'q_id': 'Q_pT_2137', 'li_text': 'pT0: No evidence of primary tumor', 'li_id': 'LI_pT0_20889', 'li_instanceguid': '20889.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '349', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 56}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': 'Primary Tumor (pT)', 'q_instanceguid': '2137.100004300', 'q_id': 'Q_pT_2137', 'li_text': 'pT1: Tumor <= 5 cm in greatest dimension, no extra-adrenal invasion', 'li_id': 'LI_pT1_2138', 'li_instanceguid': '2138.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '351', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 57}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': 'Primary Tumor (pT)', 'q_instanceguid': '2137.100004300', 'q_id': 'Q_pT_2137', 'li_text': 'pT2: Tumor > 5 cm, no extra-adrenal invasion', 'li_id': 'LI_pT2_2139', 'li_instanceguid': '2139.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '353', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 58}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': 'Primary Tumor (pT)', 'q_instanceguid': '2137.100004300', 'q_id': 'Q_pT_2137', 'li_text': 'pT3: Tumor of any size with local invasion, but not invading adjacent organs', 'li_id': 'LI_pT3_2140', 'li_instanceguid': '2140.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '355', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 59}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': 'Primary Tumor (pT)', 'q_instanceguid': '2137.100004300', 'q_id': 'Q_pT_2137', 'li_text': 'pT4: Tumor of any size with invasion of adjacent organs (kidney, diaphragm, pancreas, spleen, or liver) or large blood vessels (renal vein or vena cava)', 'li_id': 'LI_pT4_2141', 'li_instanceguid': '2141.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '357', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 60}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': 'Regional Lymph Nodes (pN) (Note H)', 'q_instanceguid': '2143.100004300', 'q_id': 'Q_pN_2143', 'li_text': 'pNX: Regional lymph nodes cannot be assessed', 'li_id': 'LI_pNX_2144', 'li_instanceguid': '2144.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '363', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 61}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': 'Regional Lymph Nodes (pN) (Note H)', 'q_instanceguid': '2143.100004300', 'q_id': 'Q_pN_2143', 'li_text': 'pN0: No regional lymph node metastasis', 'li_id': 'LI_pN0_2145', 'li_instanceguid': '2145.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '365', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 62}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': 'Regional Lymph Nodes (pN) (Note H)', 'q_instanceguid': '2143.100004300', 'q_id': 'Q_pN_2143', 'li_text': 'pN1: Metastasis in regional lymph node(s)', 'li_id': 'LI_pN1_2146', 'li_instanceguid': '2146.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '367', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 63}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': '?Distant Metastasis (pM) (Note I)', 'q_instanceguid': '2149.100004300', 'q_id': 'Q_pM_2149', 'li_text': '?Not applicable - pM cannot be determined from the submitted specimen(s)', 'li_id': 'LI_NA_20895', 'li_instanceguid': '20895.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '373', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 64}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_2136', 'section_guid': '2136.100004300', 'q_text': '?Distant Metastasis (pM) (Note I)', 'q_instanceguid': '2149.100004300', 'q_id': 'Q_pM_2149', 'li_text': 'pM1: Distant metastasis', 'li_id': 'LI_pM1_2151', 'li_instanceguid': '2151.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '375', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 65}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17884', 'section_guid': '17884.100004300', 'q_text': 'Additional Pathologic Findings', 'q_instanceguid': '39188.100004300', 'q_id': 'Q_39188', 'li_text': 'None identified', 'li_id': 'LI_None_Id_2163', 'li_instanceguid': '2163.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '388', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 66}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17884', 'section_guid': '17884.100004300', 'q_text': 'Additional Pathologic Findings', 'q_instanceguid': '39188.100004300', 'q_id': 'Q_39188', 'li_text': 'Hemorrhage', 'li_id': 'LI_Hemorrhage_20897', 'li_instanceguid': '20897.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '389', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 67}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17884', 'section_guid': '17884.100004300', 'q_text': 'Additional Pathologic Findings', 'q_instanceguid': '39188.100004300', 'q_id': 'Q_39188', 'li_text': 'Cystic change', 'li_id': 'LI_Cystic_Change_20898', 'li_instanceguid': '20898.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '390', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 68}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17884', 'section_guid': '17884.100004300', 'q_text': 'Additional Pathologic Findings', 'q_instanceguid': '39188.100004300', 'q_id': 'Q_39188', 'li_text': 'Calcifications', 'li_id': 'LI_Calcifications_20854', 'li_instanceguid': '20854.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '391', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 69}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17884', 'section_guid': '17884.100004300', 'q_text': 'Additional Pathologic Findings', 'q_instanceguid': '39188.100004300', 'q_id': 'Q_39188', 'li_text': 'Other (specify)', 'li_id': 'LI_Oth_2167', 'li_instanceguid': '2167.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '395', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 70}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17880', 'section_guid': '17880.100004300', 'q_text': 'Ancillary Studies (Note L)', 'q_instanceguid': '53231.100004300', 'q_id': 'Q_53231', 'li_text': 'Ki-67 mitotic rate (specify)', 'li_id': 'LI_41352', 'li_instanceguid': '41352.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '406', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 71}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17880', 'section_guid': '17880.100004300', 'q_text': 'Ancillary Studies (Note L)', 'q_instanceguid': '53231.100004300', 'q_id': 'Q_53231', 'li_text': 'Reticulin stain (specify type(s) and result(s))', 'li_id': 'LI_54436', 'li_instanceguid': '54436.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '411', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 72}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17880', 'section_guid': '17880.100004300', 'q_text': 'Ancillary Studies (Note L)', 'q_instanceguid': '53231.100004300', 'q_id': 'Q_53231', 'li_text': 'Other (specify type and result)', 'li_id': 'LI_52023', 'li_instanceguid': '52023.100004300', 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '416', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 73}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 1, 'parentinstanceguid': None, 'section_id': 'S_17880', 'section_guid': '17880.100004300', 'q_text': '?Comment(s)', 'q_instanceguid': '2168.100004300', 'q_id': 'Q_Comments_2168', 'li_text': None, 'li_id': None, 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': '421', 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 74}
# Form Design: <Element {urn:ihe:qrph:sdc:2016}FormDesign at 0x727f2b320fc0>

# %%
# Import NAACCR data
conn = sqlite3.connect(DB_FILEPATH)
cursor = conn.cursor()

v2_messages = glob.glob(os.path.join("../sample_data/naaccr_v2", "*.hl7"))

# Iterate over each XML file
for message in v2_messages:
    try:
        # Read the XML content
        with open(message, "r", encoding="utf-8") as file:
            message_str = file.read()

        import_data_from_hl7(cursor, message_str)
    except Exception as e:
        print(f"Error processing message: {message}: {e}")
        continue

cursor.close()
conn.commit()
conn.close()
# Out:
# INFO:crud_sqlite:Inserting new TemplateSdcClass: {'sdcformdesignid': None, 'baseuri': None, 'lineage': None, 'version': '3.007.011.1000043', 'fulluri': None, 'formtitle': 'ADRENAL GLAND', 'sdc_xml': None, 'doctype': None}
# INFO:crud_sqlite:Successfully added: {'sdcformdesignid': None, 'baseuri': None, 'lineage': None, 'version': '3.007.011.1000043', 'fulluri': None, 'formtitle': 'ADRENAL GLAND', 'sdc_xml': None, 'doctype': None, 'pk': 103}
# INFO:crud_sqlite:Successfully added: {'templateinstanceversionguid': None, 'templateinstanceversionuri': None, 'templatesdcfk': 103, 'instanceversiondate': None, 'diagreportprops': None, 'surgpathid': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'reporttext': None, 'pk': 2}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'Tumor Site', 'q_instanceguid': None, 'q_id': '2118.1000043', 'li_text': '2119.1000043', 'li_id': 'Adrenal gland', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 75}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'Procedure', 'q_instanceguid': None, 'q_id': '820603.1000043', 'li_text': '2122.1000043', 'li_id': 'Adrenalectomy, total', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 76}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'Specimen Laterality', 'q_instanceguid': None, 'q_id': '52756.1000043', 'li_text': '2126.1000043', 'li_id': 'Right', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 77}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'Histologic Subtype (Notes C, D)', 'q_instanceguid': None, 'q_id': '59852.1000043', 'li_text': '2117.1000043', 'li_id': 'Conventional adrenal cortical carcinoma', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 78}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'Mitotic Tumor Grade (required for adult patients only) (Notes C, D)', 'q_instanceguid': None, 'q_id': '820395.1000043', 'li_text': '51017.1000043', 'li_id': '?Not applicable', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 79}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'Lymphovascular Invasion (Note H)', 'q_instanceguid': None, 'q_id': '39990.1000043', 'li_text': '45031.1000043', 'li_id': 'Lymphatic invasion', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 80}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'Margin Status', 'q_instanceguid': None, 'q_id': '2153.1000043', 'li_text': '2155.1000043', 'li_id': 'Carcinoma present at margin', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 81}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'Regional Lymph Node Status', 'q_instanceguid': None, 'q_id': '372404.1000043', 'li_text': '1868.1000043', 'li_id': 'Not applicable (no regional lymph nodes submitted or found)', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 82}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'Distant Site(s) Involved, if applicable', 'q_instanceguid': None, 'q_id': '354240.1000043', 'li_text': '354245.1000043', 'li_id': '?Not applicable', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 83}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'Modified Classification (required only if applicable)', 'q_instanceguid': None, 'q_id': '820585.1000043', 'li_text': '820589.1000043', 'li_id': '?Not applicable', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 84}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'pT Category', 'q_instanceguid': None, 'q_id': '327636.1000043', 'li_text': '2139.1000043', 'li_id': 'pT2: Tumor greater than 5 cm, no extra-adrenal invasion', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 85}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'T Suffix (required only if applicable)', 'q_instanceguid': None, 'q_id': '820586.1000043', 'li_text': '820587.1000043', 'li_id': '?Not applicable', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 86}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'pN Category (Note J)', 'q_instanceguid': None, 'q_id': '327638.1000043', 'li_text': '327639.1000043', 'li_id': 'pN not assigned (no nodes submitted or found)', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 87}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'pM Category (required only if confirmed pathologically) (Note K)', 'q_instanceguid': None, 'q_id': '2149.1000043', 'li_text': '20895.1000043', 'li_id': '?Not applicable - pM cannot be determined from the submitted specimen(s)', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 88}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': 'Additional Findings', 'q_instanceguid': None, 'q_id': '39188.1000043', 'li_text': '2163.1000043', 'li_id': 'None identified', 'li_instanceguid': None, 'li_parentguid': None, 'response': None, 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 89}
# INFO:crud_sqlite:Successfully added: {'templateinstanceclassfk': 2, 'parentinstanceguid': None, 'section_id': None, 'section_guid': None, 'q_text': '?Comment(s)', 'q_instanceguid': None, 'q_id': '2168.1000043', 'li_text': '2163.1000043', 'li_id': 'None identified', 'li_instanceguid': None, 'li_parentguid': None, 'response': 'Clinical Information: Adrenal gland received in formalin. Specimen integrity: Intact. Dimensions of', 'units': None, 'units_system': None, 'datatype': None, 'response_int': None, 'response_float': None, 'response_datetime': None, 'reponse_string_nvarchar': None, 'obsdatetime': None, 'sdcorder': None, 'sdcrepeatlevel': None, 'sdccomments': None, 'personfk': None, 'encounterfk': None, 'practitionerfk': None, 'pk': 90}
# Message type: ORU^R01^ORU_R01
# Message profile: VOL_V_40_ORU_R01^NAACCR_CP
# Report type: 60568-3^SYNOPTIC REPORT^LN
# First OBX identifier: 60573-3^Report template source^LN
# Document source style: CAP eCC
# Template ID: 129.1000043^ADRENAL GLAND^CAPECC
# ! Form Title: ADRENAL GLAND
# ! Version ID: 3.007.011.1000043
# Q ID: 2118.1000043
# Q Text: Tumor Site
# Q ID: 820603.1000043
# Q Text: Procedure
# Q ID: 52756.1000043
# Q Text: Specimen Laterality
# Q ID: 59852.1000043
# Q Text: Histologic Subtype (Notes C, D)
# Q ID: 820395.1000043
# Q Text: Mitotic Tumor Grade (required for adult patients only) (Notes C, D)
# Q ID: 2129.1000043
# Q Text: Tumor Size (Notes E, F)
# @@@ Observation sub ID: 2131
# Q ID: 2129.1000043
# Q Text: Tumor Size (Notes E, F)
# Observation units: cm^CentiMeter^UCUM
# @@@ Observation sub ID: +2131.1000043
# Q ID: 820398.1000043
# Q Text: Adrenal Gland Weight (Note G)
# @@@ Observation sub ID: 44761
# Q ID: 820398.1000043
# Q Text: Adrenal Gland Weight (Note G)
# @@@ Observation sub ID: 44761
# @@@@@ Observation sub ID already exists: 44761
# Q ID: 820404.1000043
# Q Text: Site(s) Involved by Direct Tumor Extension
# @@@ Observation sub ID: 45594
# Q ID: 820404.1000043
# Q Text: Site(s) Involved by Direct Tumor Extension
# @@@ Observation sub ID: 45594
# @@@@@ Observation sub ID already exists: 45594
# Q ID: 39990.1000043
# Q Text: Lymphovascular Invasion (Note H)
# Q ID: 2153.1000043
# Q Text: Margin Status
# Q ID: 354227.1000043
# Q Text: Margin(s) Involved by Carcinoma
# @@@ Observation sub ID: 354228
# Q ID: 354227.1000043
# Q Text: Margin(s) Involved by Carcinoma
# @@@ Observation sub ID: 354228
# @@@@@ Observation sub ID already exists: 354228
# Q ID: 372404.1000043
# Q Text: Regional Lymph Node Status
# Q ID: 354240.1000043
# Q Text: Distant Site(s) Involved, if applicable
# Q ID: 820585.1000043
# Q Text: Modified Classification (required only if applicable)
# Q ID: 327636.1000043
# Q Text: pT Category
# Q ID: 820586.1000043
# Q Text: T Suffix (required only if applicable)
# Q ID: 327638.1000043
# Q Text: pN Category (Note J)
# Q ID: 2149.1000043
# Q Text: pM Category (required only if confirmed pathologically) (Note K)
# Q ID: 39188.1000043
# Q Text: Additional Findings
# Q ID: 2168.1000043
# Q Text: ?Comment(s)
# Message type: ORU^R01^ORU_R01
# Error: Unknown message profile: VOL_V_51_ORU_R01^NAACCR_CP
# Error processing message: ../sample_data/naaccr_v2/24-11-000312-2.txt.hl7: name 'exit' is not defined

# %%
import threading
import http.server
import socketserver
from contextlib import contextmanager

PORT = 8000
DIRECTORY = './public'

class Handler(http.server.SimpleHTTPRequestHandler):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, directory=DIRECTORY, **kwargs)

@contextmanager
def run_server():
    httpd = socketserver.TCPServer(('', PORT), Handler)
    httpd.allow_reuse_port = True
    server_thread = threading.Thread(target=httpd.serve_forever)
    server_thread.daemon = True
    server_thread.start()
    print(f"Serving at port {PORT}")
    try:
        yield
    finally:
        httpd.shutdown()
        httpd.server_close()
        httpd.socket.close()
        print("Server stopped")

with run_server():
    # Run until interrupt
    while True:
        pass
# Out:
# Serving at port 8000
# 127.0.0.1 - - [13/Nov/2024 19:23:42] "GET / HTTP/1.1" 304 -
# 127.0.0.1 - - [13/Nov/2024 19:23:42] "GET /sql-wasm-debug.js HTTP/1.1" 304 -
# 127.0.0.1 - - [13/Nov/2024 19:23:42] "GET /index.css HTTP/1.1" 304 -
# 127.0.0.1 - - [13/Nov/2024 19:23:42] "GET /sql-wasm-debug.wasm HTTP/1.1" 304 -
# 127.0.0.1 - - [13/Nov/2024 19:23:42] code 404, message File not found
# 127.0.0.1 - - [13/Nov/2024 19:23:42] "GET /favicon.ico HTTP/1.1" 404 -
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 43920)
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/http/server.py", line 726, in send_head
#     f = open(path, 'rb')
#         ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './public/favicon.ico'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.11/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.11/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/tmp/ipykernel_113066/2402287129.py", line 11, in __init__
#     super().__init__(*args, directory=DIRECTORY, **kwargs)
#   File "/usr/lib/python3.11/http/server.py", line 667, in __init__
#     super().__init__(*args, **kwargs)
#   File "/usr/lib/python3.11/socketserver.py", line 755, in __init__
#     self.handle()
#   File "/usr/lib/python3.11/http/server.py", line 432, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.11/http/server.py", line 420, in handle_one_request
#     method()
#   File "/usr/lib/python3.11/http/server.py", line 671, in do_GET
#     f = self.send_head()
#         ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/http/server.py", line 728, in send_head
#     self.send_error(HTTPStatus.NOT_FOUND, "File not found")
#   File "/usr/lib/python3.11/http/server.py", line 487, in send_error
#     self.wfile.write(body)
#   File "/usr/lib/python3.11/socketserver.py", line 834, in write
#     self._sock.sendall(b)
# BrokenPipeError: [Errno 32] Broken pipe
# ----------------------------------------
# 127.0.0.1 - - [13/Nov/2024 19:23:42] "GET /sdc_cdm.db HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Nov/2024 19:24:57] "GET / HTTP/1.1" 304 -
# 127.0.0.1 - - [13/Nov/2024 19:24:57] code 404, message File not found
# 127.0.0.1 - - [13/Nov/2024 19:24:57] "GET /favicon.ico HTTP/1.1" 404 -
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 44634)
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/http/server.py", line 726, in send_head
#     f = open(path, 'rb')
#         ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './public/favicon.ico'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.11/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.11/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/tmp/ipykernel_113066/2402287129.py", line 11, in __init__
#     super().__init__(*args, directory=DIRECTORY, **kwargs)
#   File "/usr/lib/python3.11/http/server.py", line 667, in __init__
#     super().__init__(*args, **kwargs)
#   File "/usr/lib/python3.11/socketserver.py", line 755, in __init__
#     self.handle()
#   File "/usr/lib/python3.11/http/server.py", line 432, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.11/http/server.py", line 420, in handle_one_request
#     method()
#   File "/usr/lib/python3.11/http/server.py", line 671, in do_GET
#     f = self.send_head()
#         ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/http/server.py", line 728, in send_head
#     self.send_error(HTTPStatus.NOT_FOUND, "File not found")
#   File "/usr/lib/python3.11/http/server.py", line 487, in send_error
#     self.wfile.write(body)
#   File "/usr/lib/python3.11/socketserver.py", line 834, in write
#     self._sock.sendall(b)
# BrokenPipeError: [Errno 32] Broken pipe
# ----------------------------------------
# 127.0.0.1 - - [13/Nov/2024 19:24:57] "GET /sdc_cdm.db HTTP/1.1" 304 -
# Server stopped
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 31
#      27         print("Server stopped")
#      29 with run_server():
#      30     # Run until interrupt
# ---> 31     while True:
#      32         pass
#
# KeyboardInterrupt:
