# %%
# %pip install -r ../requirements.txt

import sqlite3
import glob
import os
from lxml import etree
from import_sdc_form_sqlite import process_xml
from import_vol_v_message_sqlite import import_data_from_hl7

DB_FILEPATH = "public/sdc_cdm.db"
# Out:
# Requirement already satisfied: lxml==5.3.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (5.3.0)
# Requirement already satisfied: SQLAlchemy==2.0.35 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (2.0.35)
# Requirement already satisfied: psycopg2-binary==2.9.9 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (2.9.9)
# Requirement already satisfied: notebook==7.2.2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (7.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from SQLAlchemy==2.0.35->-r ../requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from SQLAlchemy==2.0.35->-r ../requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from notebook==7.2.2->-r ../requirements.txt (line 4)) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from notebook==7.2.2->-r ../requirements.txt (line 4)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from notebook==7.2.2->-r ../requirements.txt (line 4)) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from notebook==7.2.2->-r ../requirements.txt (line 4)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from notebook==7.2.2->-r ../requirements.txt (line 4)) (6.4.1)
# Requirement already satisfied: anyio>=3.1.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (4.6.2.post1)
# Requirement already satisfied: argon2-cffi>=21.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.21.0)
# Requirement already satisfied: pyzmq>=24 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (66.1.1)
# Requirement already satisfied: babel>=2.10 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: certifi in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.8.7)
# Requirement already satisfied: ipython>=7.23.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (8.29.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: psutil in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (6.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (4.3.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (6.2.0)
# Requirement already satisfied: defusedxml in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.18.0)
# Requirement already satisfied: tinycss2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.2.3)
# Requirement already satisfied: ptyprocess in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: webencodings in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: decorator in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.0.48)
# Requirement already satisfied: stack-data in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (4.9.0)
# Requirement already satisfied: fqdn in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: isoduration in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: uri-template in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (24.8.0)
# Requirement already satisfied: six>=1.5 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.6)
# Requirement already satisfied: pycparser in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.8.4)
# Requirement already satisfied: wcwidth in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.4.1)
# Requirement already satisfied: pure-eval in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /workspaces/SDC-CDM/venv/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r ../requirements.txt (line 4)) (2.9.0.20241003)
# Note: you may need to restart the kernel to use updated packages.

# %%
if os.path.exists(DB_FILEPATH):
    print(f"Deleting existing database file: {DB_FILEPATH}")
    os.remove(DB_FILEPATH)

# Connect to the SQLite database (creates the database file if it doesn't exist)
conn = sqlite3.connect(DB_FILEPATH)
cursor = conn.cursor()
print("Connected to the SQLite database.")

# Get a list of all .sql files in the ./ddl directory
sql_files = glob.glob('../database/ddl/sqlite/*.sql')

# Sort the files alphanumerically
sql_files.sort()

# Display the files to be executed
print("SQL files to be executed in order:")
for file in sql_files:
    print(os.path.basename(file))

# Execute each SQL file
for sql_file in sql_files:
    print(f"\nExecuting {os.path.basename(sql_file)}...")
    with open(sql_file, 'r') as file:
        sql_script = file.read()
    try:
        cursor.executescript(sql_script)
        print(f"Finished executing {os.path.basename(sql_file)}.")
    except Exception as e:
        print(f"An error occurred while executing {os.path.basename(sql_file)}: {e}")

# Commit changes and close the connection
conn.commit()
conn.close()

print("Database changes committed and connection closed.")
# Out:
# Deleting existing database file: public/sdc_cdm.db
# Connected to the SQLite database.
# SQL files to be executed in order:
# 1_OMOPCDM_sqlite_5.4_ddl.sql
# 2_OMOPCDM_sqlite_5.4_primary_keys.sql
# 3_OMOPCDM_sqlite_5.4_indices.sql
# 4_OMOPCDM_sqlite_5.4_constraints.sql
# 5_SDC_sqlite.sql
#
# Executing 1_OMOPCDM_sqlite_5.4_ddl.sql...
# Finished executing 1_OMOPCDM_sqlite_5.4_ddl.sql.
#
# Executing 2_OMOPCDM_sqlite_5.4_primary_keys.sql...
# Finished executing 2_OMOPCDM_sqlite_5.4_primary_keys.sql.
#
# Executing 3_OMOPCDM_sqlite_5.4_indices.sql...
# Finished executing 3_OMOPCDM_sqlite_5.4_indices.sql.
#
# Executing 4_OMOPCDM_sqlite_5.4_constraints.sql...
# Finished executing 4_OMOPCDM_sqlite_5.4_constraints.sql.
#
# Executing 5_SDC_sqlite.sql...
# Finished executing 5_SDC_sqlite.sql.
# Database changes committed and connection closed.

# %%
conn = sqlite3.connect(DB_FILEPATH)
cursor = conn.cursor()

namespaces = {
    "sdc": "urn:ihe:qrph:sdc:2016",
    "xsi": "http://www.w3.org/2001/XMLSchema-instance",
    "xsd": "http://www.w3.org/2001/XMLSchema",
}

# Import SDC templates
v2_messages = glob.glob(os.path.join("../sample_data/sdc_templates", "*.xml"))

# Iterate over each XML file
for message in v2_messages:
    # Read the XML content
    with open(message, "r", encoding="utf-8") as file:
        message_str = file.read()

    tree = etree.parse(message)
    root = tree.getroot()

    form_design = root.find("sdc:FormDesign", namespaces)
    if form_design is None:
        form_design = root

    if form_design is None:
        print(f"No Form Design found in {os.path.basename(message)}")
        continue
    print(f"Form Design: {form_design}")

    # Extract column values from the XML content
    sdcformdesignid = form_design.get("ID")
    baseuri = form_design.get("baseURI")
    lineage = form_design.get("lineage")
    version = form_design.get("version")
    fulluri = form_design.get("fullURI")
    formtitle = form_design.get("formTitle")
    sdc_xml = etree.tostring(form_design).decode("utf-8")
    doctype = "FD"  # TODO: Parse from fullURI

    # Insert the data into the database
    try:
        cursor.execute(
            """
            INSERT INTO main.templatesdcclass (
                sdcformdesignid, baseuri, lineage, version, fulluri, formtitle, sdc_xml, doctype
            ) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
        """,
            (
                sdcformdesignid,
                baseuri,
                lineage,
                version,
                fulluri,
                formtitle,
                sdc_xml,
                doctype,
            ),
        )
        print(f"Inserted data from {os.path.basename(message)} into the database.")
    except Exception as e:
        print(
            f"An error occurred while inserting data from {os.path.basename(message)}: {e}"
        )

# Commit the changes
conn.commit()
print("All XML data has been inserted into the database.")

cursor.execute("SELECT COUNT(*) FROM main.templatesdcclass;")
count = cursor.fetchone()[0]
print(f"\nTotal records inserted: {count}")

# Commit changes and close the connection
conn.close()

# %%
# Import SDC forms
conn = sqlite3.connect(DB_FILEPATH)
cursor = conn.cursor()

# Import SDC templates
v2_messages = glob.glob(os.path.join("../sample_data/sdc_xml", "*.xml"))

# Iterate over each XML file
for message in v2_messages:
    # Read the XML content
    with open(message, "r", encoding="utf-8") as file:
        message_str = file.read()

    tree = etree.parse(message)
    root = tree.getroot()
    process_xml(root, cursor)

cursor.close()
conn.commit()
conn.close()

# %%
# Import NAACCR data
conn = sqlite3.connect(DB_FILEPATH)
cursor = conn.cursor()

v2_messages = glob.glob(os.path.join("../sample_data/naaccr_v2", "*.hl7"))

# Iterate over each XML file
for message in v2_messages:
    try:
        # Read the XML content
        with open(message, "r", encoding="utf-8") as file:
            message_str = file.read()

        import_data_from_hl7(cursor, message_str)
    except Exception as e:
        print(f"Error processing message: {message}: {e}")
        continue

cursor.close()
conn.commit()
conn.close()

# %%
import threading
import http.server
import socketserver
from contextlib import contextmanager

PORT = 8000
DIRECTORY = './public'

class Handler(http.server.SimpleHTTPRequestHandler):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, directory=DIRECTORY, **kwargs)

@contextmanager
def run_server():
    httpd = socketserver.TCPServer(('', PORT), Handler)
    httpd.allow_reuse_port = True
    server_thread = threading.Thread(target=httpd.serve_forever)
    server_thread.daemon = True
    server_thread.start()
    print(f"Serving at port {PORT}")
    try:
        yield
    finally:
        httpd.shutdown()
        httpd.server_close()
        httpd.socket.close()
        print("Server stopped")

with run_server():
    # Run until interrupt
    while True:
        pass
