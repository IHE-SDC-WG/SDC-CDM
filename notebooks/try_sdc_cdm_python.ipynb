# %%
# Dependency management
try:
    from lxml import etree
except ImportError:
    print("Installing lxml...")
    # %pip install lxml==5.3.0
    from lxml import etree  # Re-import after installation

# Standard library imports
import sqlite3
import glob
import os

# Local module imports
from python_cdm_utils.import_sdc_form_sqlite import process_xml
from python_cdm_utils.import_vol_v_message_sqlite import import_data_from_hl7
from python_cdm_utils.crud_sqlite import create_template_sdc_class

# Three-schema SQLite layout: a single "control" database ATTACHes three sibling
# files exposed as the logical schemas `omop` (stock OMOP CDM 5.4), `naaccr`, and
# `sdc`. See database/SCHEMA_ARCHITECTURE.md. File names mirror the C#
# SdcCdmInSqlite convention (<base>.<schema>.db) so serve_db.py exposes all four.
DB_DIR = "public"
CONTROL_DB = os.path.join(DB_DIR, "sdc_cdm.db")
SCHEMA_DBS = {
    "omop": os.path.join(DB_DIR, "sdc_cdm.omop.db"),
    "naaccr": os.path.join(DB_DIR, "sdc_cdm.naaccr.db"),
    "sdc": os.path.join(DB_DIR, "sdc_cdm.sdc.db"),
}


def connect():
    """Open the control DB with the omop/naaccr/sdc schema databases attached."""
    conn = sqlite3.connect(CONTROL_DB)
    conn.execute("PRAGMA foreign_keys = ON;")
    for schema, path in SCHEMA_DBS.items():
        conn.execute(f"ATTACH DATABASE '{path}' AS {schema};")
    return conn

# %%
os.makedirs(DB_DIR, exist_ok=True)

# Start fresh: remove the control DB and every attached schema file.
for path in [CONTROL_DB, *SCHEMA_DBS.values()]:
    if os.path.exists(path):
        print(f"Deleting existing database file: {path}")
        os.remove(path)

conn = connect()
cursor = conn.cursor()
print("Connected to the control database with omop/naaccr/sdc attached.")

# Run the schema DDL in deterministic order. These files are schema-qualified
# (e.g. CREATE TABLE omop.person ...), so the ATTACH above is required for them
# to land in the correct database file.
sql_files = (
    sorted(glob.glob("../database/schemas/omop/ddl/sqlite/*.sql"))
    + sorted(glob.glob("../database/schemas/naaccr/ddl/sqlite/*.sql"))
    + sorted(glob.glob("../database/schemas/sdc/ddl/sqlite/*.sql"))
)

print("SQL files to be executed in order:")
for file in sql_files:
    print(f"  {os.path.relpath(file)}")

for sql_file in sql_files:
    with open(sql_file, "r") as file:
        try:
            cursor.executescript(file.read())
        except Exception as e:
            print(f"An error occurred while executing {os.path.basename(sql_file)}: {e}")
            raise

conn.commit()
conn.close()
print("\nSchema built across the omop, naaccr, and sdc databases.")

# %%
# Seed the minimal OMOP concepts referenced by the data and the bridge ETL.
# omop.person.gender/race/ethnicity_concept_id are NOT NULL and reference
# omop.concept (FKs enforced within the attached omop database), so the gender
# concepts must exist before importing NAACCR persons. 32817 (EHR) and 1147289
# (note.note_id) are used by database/etl/sqlite/1_naaccr_sdc_to_omop.sql.
conn = connect()
conn.executescript(
    """
    INSERT INTO omop.concept (
        concept_id, concept_name, domain_id, vocabulary_id, concept_class_id,
        concept_code, valid_start_date, valid_end_date
    )
    VALUES
        (0, 'Unknown', 'Metadata', 'None', 'None', '0', '1970-01-01', '2099-12-31'),
        (8507, 'MALE', 'Gender', 'Gender', 'Gender', 'M', '1970-01-01', '2099-12-31'),
        (8532, 'FEMALE', 'Gender', 'Gender', 'Gender', 'F', '1970-01-01', '2099-12-31'),
        (32817, 'EHR', 'Type Concept', 'Type Concept', 'Type Concept', 'EHR', '1970-01-01', '2099-12-31'),
        (1147289, 'note.note_id', 'Metadata', 'CDM', 'Field', 'note.note_id', '1970-01-01', '2099-12-31');
    """
)
conn.commit()
conn.close()
print("Seeded baseline OMOP concepts (0, 8507, 8532, 32817, 1147289).")

# %%
# Import SDC templates into sdc.template_sdc
conn = connect()
cursor = conn.cursor()

namespaces = {
    "sdc": "urn:ihe:qrph:sdc:2016",
    "xsi": "http://www.w3.org/2001/XMLSchema-instance",
    "xsd": "http://www.w3.org/2001/XMLSchema",
}

template_files = glob.glob(os.path.join("../sample_data/sdc_templates", "*.xml"))

for template in template_files:
    tree = etree.parse(template)
    root = tree.getroot()

    form_design = root.find("sdc:FormDesign", namespaces)
    if form_design is None:
        form_design = root
    if form_design is None:
        print(f"No Form Design found in {os.path.basename(template)}")
        continue

    try:
        create_template_sdc_class(
            cursor=cursor,
            sdc_form_design_sdcid=form_design.get("ID"),
            base_uri=form_design.get("baseURI"),
            lineage=form_design.get("lineage"),
            version=form_design.get("version"),
            full_uri=form_design.get("fullURI"),
            form_title=form_design.get("formTitle"),
            sdc_xml=etree.tostring(form_design).decode("utf-8"),
            doc_type="FD",  # TODO: Parse from fullURI
        )
        print(f"Inserted template from {os.path.basename(template)}.")
    except Exception as e:
        print(f"An error occurred while inserting {os.path.basename(template)}: {e}")

conn.commit()

cursor.execute("SELECT COUNT(*) FROM sdc.template_sdc;")
print(f"\nTotal sdc.template_sdc records: {cursor.fetchone()[0]}")

conn.close()

# %%
# Import SDC form submissions into sdc.template_instance / sdc.sdc_form_answer
conn = connect()
cursor = conn.cursor()

form_files = glob.glob(os.path.join("../sample_data/sdc_xml", "*.xml"))

for form in form_files:
    try:
        tree = etree.parse(form)
        root = tree.getroot()
        process_xml(root, cursor)
    except Exception as e:
        print(f"Error processing form {os.path.basename(form)}: {e}")
        continue

conn.commit()
cursor.execute("SELECT COUNT(*) FROM sdc.sdc_form_answer;")
print(f"Total sdc.sdc_form_answer records after form import: {cursor.fetchone()[0]}")
conn.close()

# %%
# Import NAACCR Volume V (HL7 v2) messages into omop.person, sdc.sdc_report,
# and naaccr.naaccr_value
conn = connect()
cursor = conn.cursor()

v2_messages = glob.glob(os.path.join("../sample_data/naaccr_v2", "*.hl7"))

for message in v2_messages:
    try:
        with open(message, "r", encoding="utf-8") as file:
            message_str = file.read()
        import_data_from_hl7(cursor, message_str)
    except Exception as e:
        print(f"Error processing message: {message}: {e}")
        continue

conn.commit()
for table in ("omop.person", "sdc.sdc_report", "naaccr.naaccr_value"):
    cursor.execute(f"SELECT COUNT(*) FROM {table};")
    print(f"{table}: {cursor.fetchone()[0]} rows")
conn.close()

# %%
# Bridge: read naaccr + sdc and write standard OMOP rows (omop.note +
# omop.measurement). OMOP rows point back to source via note_source_value
# (= report accession) and measurement_event_id (= note.note_id).
conn = connect()
cursor = conn.cursor()

with open("../database/etl/sqlite/1_naaccr_sdc_to_omop.sql", "r") as f:
    cursor.executescript(f.read())

conn.commit()
for table in ("omop.note", "omop.measurement"):
    cursor.execute(f"SELECT COUNT(*) FROM {table};")
    print(f"{table}: {cursor.fetchone()[0]} rows")
conn.close()

# %%
# Round-trip query: each bridged OMOP measurement recovers its NAACCR item and
# its source synoptic report (note_source_value == report accession) using only
# standard OMOP columns -- no SDC-specific columns on the OMOP tables.
conn = connect()
cursor = conn.cursor()

print("OMOP measurement -> source report (via measurement_event_id = note.note_id):")
for row in cursor.execute(
    """
    SELECT m.measurement_source_value AS naaccr_item,
           m.value_source_value       AS value_code,
           m.value_as_number          AS value_num,
           n.note_source_value        AS report_accession
    FROM omop.measurement m
    JOIN omop.note n ON n.note_id = m.measurement_event_id
    LIMIT 20;
    """
):
    print(f"  item={row[0]!s:>8}  code={row[1]!s:>8}  num={row[2]!s:>8}  accession={row[3]}")

# Guard: the OMOP tables must stay vanilla (no sdc_* columns leaked in).
for table in ("measurement", "observation"):
    cols = {r[1] for r in cursor.execute(f"PRAGMA omop.table_info({table})")}
    leaked = {c for c in cols if c.startswith("sdc_")}
    assert not leaked, f"omop.{table} unexpectedly has SDC columns: {leaked}"
print("\nOK: omop.measurement / omop.observation contain no sdc_* columns.")

conn.close()
